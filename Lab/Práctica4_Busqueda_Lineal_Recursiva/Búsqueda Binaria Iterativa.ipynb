# %%
import numpy as np
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
import random
# %matplotlib inline
import math
from Node import *

# %%
counter = 0
counterForSortingAlgorithms = 0
def binarySearchIterative(listOfItems, city):
	global counter
	leftIndex = 0
	rightIndex = len(listOfItems)-1
	while leftIndex <= rightIndex:
		counter += 1
		midIndex = math.floor((leftIndex + rightIndex) / 2)
		midIndex = int(midIndex)
		if listOfItems[midIndex].city == city:
			return midIndex
		elif listOfItems[midIndex].city < city:
			leftIndex = midIndex + 1
		else:
			rightIndex = midIndex -1
	return -1

# %%
def bubble_sort(a):
	global counterForSortingAlgorithms
	interchange = 1
	i = 0
	j = 0
	n = len(a)
	while i < n-1 and interchange == 1: 
		counterForSortingAlgorithms += 1
		interchange = 0
		for j in xrange(n-i-1):
			counterForSortingAlgorithms += 1
			if a[j].city > a[j + 1].city:
				interchange = 1
				a[j].city, a[j+1].city = a[j+1].city, a[j].city
		i += 1
	return a

def Merge(A, p, q, r):
	global counterForSortingAlgorithms
	arrIzq = A[p:q+1]
	arrDer = A[q+1:r+1]
	izq = 0
	der = 0
	for k in xrange(p,r+1):
		if (der >= len(arrDer)) or (izq < len(arrIzq) and arrIzq[izq].city < arrDer[der].city):
			A[k] = arrIzq[izq]
			izq += 1
			counterForSortingAlgorithms += 1
		else:
			A[k] = arrDer[der]
			der += 1
			counterForSortingAlgorithms += 1
			

def MergeSort(A, p, r):
	global counterForSortingAlgorithms
	if p >= r:
		counterForSortingAlgorithms += 1
		return
	else:
		counterForSortingAlgorithms += 1
		q = (p + r ) / 2
		MergeSort(A, p, q)
		MergeSort(A, q + 1, r)
		Merge(A, p, q, r)
	return A

# %%
#Bubble Sort

listOfItems = readFromFile()
printList(listOfItems)
# Out:
# 1, Malie
# 2, Fresno
# 3, Aguachica
# 4, Yambrasbamba
# 5, Chengnan
# 6, Jakarata
# 7, Jaquimeyes
# 8, Santa Cruz
# 9, Torre
# 10, Duraznopampa

# %%
counterForSortingAlgorithms = 0
listOfItems = bubble_sort(listOfItems)
print("Now sorted: ")
printList(listOfItems)
# Out:
# Now sorted:
# 1, Aguachica
# 2, Chengnan
# 3, Duraznopampa
# 4, Fresno
# 5, Jakarata
# 6, Jaquimeyes
# 7, Malie
# 8, Santa Cruz
# 9, Torre
# 10, Yambrasbamba

# %%
counter = 0
print("Binary Search with Bubble Sort")
print("\tLooking for 'Jakarata'")
print("\tFound at: " + str(binarySearchIterative(listOfItems, 'Jakarata')) + " with a time of: " + str(counter ))
counter = 0
print("\tLooking for 'Aguachica'")
print("\tFound at: " + str(binarySearchIterative(listOfItems, 'Aguachica')) + " with a time of: " + str(counter ))
# Out:
# Binary Search with Bubble Sort
# 	Looking for 'Jakarata'
# 	Found at: 4 with a time of: 1
# 	Looking for 'Aguachica'
# 	Found at: 0 with a time of: 3

# %%
#Binary Search Best Case 
print("Binary Search Best Case")
listOfItems = readFromFile()
listOfItems = bubble_sort(listOfItems)
counterForSortingAlgorithms = 0
listOfItems = bubble_sort(listOfItems)
print("Tiempo que le tomo al algoritmo -> " + str(counterForSortingAlgorithms) + '\n')
x = []
yBest = []
listToIterate = []
for i in range(len(listOfItems)):
	counter = 0
	x.append(i+1)
	listToIterate = listOfItems[:i+1]
	mid = math.floor((0 + (len(listToIterate)-1)) / 2)
	city = listToIterate[int(mid)].city
	binarySearchIterative(listToIterate, city)
	yBest.append(counterForSortingAlgorithms + counter)
print(yBest)
plt.plot( x, yBest, 'r')
plt.show()
# Out:
# Binary Search Best Case
# Tiempo que le tomo al algoritmo -> 10
#
# [11, 11, 11, 11, 11, 11, 11, 11, 11, 11]

# %%
# BubbleSort Average Case 
#print("Bubble Sort Average Case")
counterForSortingAlgorithms = 0
listOfItems = readFromFile()
listOfItems = bubble_sort(listOfItems)
print("Tiempo que le tomo al algoritmo -> " + str(counterForSortingAlgorithms) + '\n')
yAverage = []
listToIterate = []
for i in range(len(listOfItems)):
	counter = 0
	listToIterate = listOfItems[:i+1]
	mid = math.floor((0 + (len(listToIterate)-1)) / 2)
	city = listToIterate[int(mid)].city
	binarySearchIterative(listToIterate, city)
	yAverage.append(counterForSortingAlgorithms + counter)
print(yAverage)

plt.plot( x, yAverage, 'r')
plt.show()
# Out:
# Tiempo que le tomo al algoritmo -> 52
#
# [53, 53, 53, 53, 53, 53, 53, 53, 53, 53]

# %%
# BubbleSort Worst Case
#print("Bubble Sort Worst Case") 
counterForSortingAlgorithms = 0
listOfItems = readFromFile()
print("Antes de desordenar")
printList(listOfItems)
print("Lista desordenada")
listOfItems.reverse()
printList(listOfItems)
listOfItems = bubble_sort(listOfItems)
print("Tiempo que le tomo al algoritmo -> " + str(counterForSortingAlgorithms) + '\n')
yWorst = []
listToIterate = []
for i in range(len(listOfItems)):
	counter = 0
	listToIterate = listOfItems[:i+1]
	mid = math.floor((0 + (len(listToIterate)-1)) / 2)
	city = listToIterate[int(mid)].city
	binarySearchIterative(listToIterate, city)
	yWorst.append(counterForSortingAlgorithms + counter)
print(yWorst)


plt.plot( x, yWorst, 'r')
plt.show()
# Out:
# Antes de desordenar
# 1, Malie
# 2, Fresno
# 3, Aguachica
# 4, Yambrasbamba
# 5, Chengnan
# 6, Jakarata
# 7, Jaquimeyes
# 8, Santa Cruz
# 9, Torre
# 10, Duraznopampa
# Lista desordenada
# 10, Duraznopampa
# 9, Torre
# 8, Santa Cruz
# 7, Jaquimeyes
# 6, Jakarata
# 5, Chengnan
# 4, Yambrasbamba
# 3, Aguachica
# 2, Fresno
# 1, Malie
# Tiempo que le tomo al algoritmo -> 52
#
# [53, 53, 53, 53, 53, 53, 53, 53, 53, 53]

# %%
def bubble_sortGraf(a):
	global counterForSortingAlgorithms
	interchange = 1
	i = 0
	j = 0
	n = len(a)
	while i < n-1 and interchange == 1: 
		counterForSortingAlgorithms += 1
		interchange = 0
		for j in xrange(n-i-1):
			counterForSortingAlgorithms += 1
			if a[j] > a[j + 1]:
				interchange = 1
				a[j], a[j+1] = a[j+1], a[j]
		i += 1
	return a

# %%
counter = 0
counterForSortingAlgorithms = 0
def binarySearchIterativeGraf(listOfItems, number):
	global counter
	leftIndex = 0
	rightIndex = len(listOfItems)-1
	while leftIndex <= rightIndex:
		counter += 1
		midIndex = math.floor((leftIndex + rightIndex) / 2)
		midIndex = int(midIndex)
		if listOfItems[midIndex] == number:
			return midIndex
		elif listOfItems[midIndex] < number:
			leftIndex = midIndex + 1
		else:
			rightIndex = midIndex -1
	return -1

# %%
#Binary Search Average Case 
	# BubbleSort Best Case 
print("Binary Search Average Case -> BubbleSort Best Case ")
#print("Bubble Sort Best Case")
randomList= []
for x in range(10):
    randomList.append(random.randint(0,400))
randomList.sort()
counterForSortingAlgorithms = 0
listOfItems = bubble_sortGraf(randomList)
print("Tiempo que le tomo al algoritmo -> " + str(counterForSortingAlgorithms) + '\n')
x = []
yBest = []
listToIterate = []
for i in range(len(listOfItems)):
	counter = 0
	x.append(i+1)
	listToIterate = randomList[:i+1]
	randomElement = random.randint(0,len(listToIterate)-1)
	number = listToIterate[randomElement]
	binarySearchIterativeGraf(listToIterate, number)
	yBest.append(counterForSortingAlgorithms + counter)
print(yBest)

plt.plot( x, yBest, 'r')
plt.show()
# Out:
# Binary Search Average Case -> BubbleSort Best Case
# Tiempo que le tomo al algoritmo -> 10
#
# [11, 12, 12, 13, 13, 13, 13, 14, 14, 12]

# %%
# BubbleSort Average Case
print("Bubble Sort Average Case")
counterForSortingAlgorithms = 0
listOfItems = readFromFile()
listOfItems = bubble_sort(listOfItems)
print("Tiempo que le tomo al algoritmo -> " + str(counterForSortingAlgorithms) + '\n')
yAverage = []
listToIterate = []
x = []
for i in range(len(listOfItems)):
	x.append(i)
	counter = 0
	listToIterate = listOfItems[:i+1]
	randomElement = random.randint(0,len(listToIterate)-1)
	city = listToIterate[randomElement].city
	binarySearchIterative(listToIterate, city)
	yAverage.append(counterForSortingAlgorithms + counter)
print(yAverage) 

plt.plot( x, yAverage, 'r')
plt.show()
# Out:
# Bubble Sort Average Case
# Tiempo que le tomo al algoritmo -> 52
#
# [53, 54, 54, 54, 54, 55, 55, 53, 55, 55]

# %%
# BubbleSort Worst Case 
print("Bubble Sort Worst Case")
counterForSortingAlgorithms = 0
listOfItems = readFromFile()
listOfItems.reverse()
listOfItems = bubble_sort(listOfItems)
print("Tiempo que le tomo al algoritmo -> " + str(counterForSortingAlgorithms) + '\n')
yWorst = []
listToIterate = []
for i in range(len(listOfItems)):
	counter = 0
	listToIterate = listOfItems[:i+1]
	randomElement = random.randint(0,len(listToIterate)-1)
	city = listToIterate[randomElement].city
	binarySearchIterative(listToIterate, city)
	yWorst.append(counterForSortingAlgorithms + counter)
print(yWorst)

plt.plot( x, yWorst, 'r')
plt.show()
# Out:
# Bubble Sort Worst Case
# Tiempo que le tomo al algoritmo -> 52
#
# [53, 54, 54, 55, 54, 55, 55, 54, 54, 56]

# %%
#Binary Search Worst Case 
print("Binary Search Worst Case -> Bubble Sort Best Case")
	# BubbleSort Best Case 
listOfItems = readFromFile()
listOfItems = bubble_sort(listOfItems)
counterForSortingAlgorithms = 0
listOfItems = bubble_sort(listOfItems)
x = []
yBest = []
listToIterate = []
for i in range(len(listOfItems)):
	counter = 0
	x.append(i+1)
	listToIterate = listOfItems[:i+1]
	binarySearchIterative(listToIterate, "xxxxxxxx")
	yBest.append(counterForSortingAlgorithms + counter)
print(yBest)

plt.plot( x, yBest, 'r')
plt.show()
# Out:
# Binary Search Worst Case -> Bubble Sort Best Case
# [11, 12, 12, 13, 13, 13, 13, 14, 14, 14]

# %%
print("BubbleSort Average Case")
counterForSortingAlgorithms = 0
listOfItems = readFromFile()
listOfItems = bubble_sort(listOfItems)
yAverage = []
listToIterate = []
for i in range(len(listOfItems)):
	counter = 0
	listToIterate = listOfItems[:i+1]
	binarySearchIterative(listToIterate, "xxxxxxxx")
	yAverage.append(counterForSortingAlgorithms + counter)
print(yAverage) 

plt.plot( x, yAverage, 'r')
plt.show()
# Out:
# BubbleSort Average Case
# [53, 54, 54, 55, 55, 55, 55, 56, 56, 56]

# %%
print("BubbleSort Worst Case ")
counterForSortingAlgorithms = 0
listOfItems = readFromFile()
listOfItems.reverse()
listOfItems = bubble_sort(listOfItems)
yWorst = []
listToIterate = []
for i in range(len(listOfItems)):
	counter = 0
	listToIterate = listOfItems[:i+1]
	binarySearchIterative(listToIterate, "xxxxxxxx")
	yWorst.append(counterForSortingAlgorithms + counter)
print(yWorst)

plt.plot( x, yWorst, 'r')
plt.show()
# Out:
# BubbleSort Worst Case
# [53, 54, 54, 55, 55, 55, 55, 56, 56, 56]

# %%
#Merge Sort
print("Binary Search with Merge Sort")
# Out:
# Binary Search with Merge Sort

# %%
#Merge Sort

listOfItems = readFromFile()
printList(listOfItems)
# Out:
# 1, Kastsyukovichy
# 2, Kholmsk
# 3, Armenia
# 4, Essang
# 5, Jianshan
# 6, Yangba
# 7, Malayal
# 8, Várzea Alegre
# 9, Mogi Mirim
# 10, Vadstena
# 11, Salgar
# 12, Aguas del Padre
# 13, Tambov
# 14, Bukonyo
# 15, Alor Setar
# 16, Bhokadoke
# 17, Gulod
# 18, Kangdong-ŭp
# 19, Randuagung
# 20, Urechcha
# 21, Inkerman
# 22, San Diego
# 23, Wadeng
# 24, Stanovoye
# 25, Huapi
# 26, Partille
# 27, Entre Rios
# 28, Olofström
# 29, Gândara
# 30, Hallstahammar
# 31, Diré
# 32, Banjar
# 33, Šardice
# 34, Kedian
# 35, Melun
# 36, Gucheng
# 37, Campos Gerais
# 38, Torbay
# 39, Kozakai-chō
# 40, Épinal
# 41, Luleå
# 42, Shankill
# 43, Canalete
# 44, Mulyadadi
# 45, Voronezh
# 46, Fagatogo
# 47, Morrelgonj
# 48, San Miguel
# 49, Juegang
# 50, Lin’an
# 51, Takamatsu-shi
# 52, Klinan
# 53, Qarqīn
# 54, Pinheiro
# 55, Caotan
# 56, Parista
# 57, Meilisi
# 58, Uva
# 59, Voinjama
# 60, Topchikha
# 61, Głogówek
# 62, Dayuanhuizu
# 63, Le Mans
# 64, Xinan
# 65, Ołpiny
# 66, Orodara
# 67, Yasothon
# 68, Menggala
# 69, Jammā‘īn
# 70, Fermont
# 71, Pau
# 72, Kaca
# 73, Bern
# 74, Basel
# 75, Bolnisi
# 76, Suren
# 77, Borek
# 78, Xiluo
# 79, Mbale
# 80, Rabāţ-e Sangī-ye Pā’īn
# 81, Ciroyom
# 82, Gorodishche
# 83, Sidomekar
# 84, Las Palmas
# 85, Preko
# 86, Bambous Virieux
# 87, Sitajara
# 88, Xinbu
# 89, Langpas
# 90, Zhulin
# 91, Lae
# 92, Vila Nova
# 93, Liangbing
# 94, Luna
# 95, Huesca
# 96, Wiri
# 97, Ts’khinvali
# 98, Ozatlán
# 99, Luleå
# 100, Mesa
# 101, Mayorga
# 102, Cincinnati
# 103, Lāliān
# 104, Mendoza
# 105, Budapest
# 106, Lluka e Eperme
# 107, Longmiao
# 108, Muqui
# 109, Kotlyarevskaya
# 110, Huancheng
# 111, Ishimbay
# 112, Yanglinqiao
# 113, Basqal
# 114, Nueva Ocotepeque
# 115, Marechal Cândido Rondon
# 116, Vila
# 117, Fort Worth
# 118, Simbal
# 119, Kítsi
# 120, Alchevs’k
# 121, Lindavista
# 122, Tarragona
# 123, Florencia
# 124, Jetis
# 125, Nyíregyháza
# 126, Campamento
# 127, Cauday
# 128, Linquan
# 129, Cái Dầu
# 130, Hexi
# 131, Viljandi
# 132, Jāmpur
# 133, Sukojember
# 134, Shouchun
# 135, Skoki
# 136, Caldono
# 137, Boulaide
# 138, Taobei
# 139, Wenfeng Zhen
# 140, Grebnevo
# 141, Hougang
# 142, Hejiang
# 143, Qaffīn
# 144, Lamoso
# 145, Horad Krychaw
# 146, São Torcato
# 147, Volzhskiy
# 148, Toledo
# 149, Bijaepasu
# 150, Velká Polom
# 151, Medicine Hat
# 152, Lillehammer
# 153, Simuay
# 154, Liushi
# 155, Wan Yai
# 156, Qabqir
# 157, Sison
# 158, Antipolo
# 159, Peresvet
# 160, Yanmen
# 161, Nanning
# 162, Chilecito
# 163, Padangtikar
# 164, Ropa
# 165, Stan-Bekhtemir
# 166, New Agutaya
# 167, Toulon
# 168, Buenavista
# 169, Joaquín V. González
# 170, Soi Dao
# 171, Pushkinskiye Gory
# 172, Novyye Kuz’minki
# 173, Bondoboghila
# 174, Kribi
# 175, London
# 176, Thị Trấn Quảng Uyên
# 177, Tulsa
# 178, Biharamulo
# 179, Santa Elena
# 180, Babakan Baru
# 181, Saint-Denis
# 182, Armenta
# 183, Trzebinia
# 184, Gardanne
# 185, Tuen Mun
# 186, Huangcun
# 187, Hŭkkyo-ri
# 188, Limon
# 189, Ambilobe
# 190, Bābolsar
# 191, Kelaniya
# 192, Longquan
# 193, Vorob’yovo
# 194, Shizukuishi
# 195, Gontar
# 196, Krajan
# 197, Chanuman
# 198, Duofudu
# 199, Rudnya
# 200, Junkou
# 201, Gonzalo Pizarro
# 202, Palpalá
# 203, Camino Real
# 204, Kalapagada
# 205, Gaocheng
# 206, Voinjama
# 207, Shangshuai
# 208, Gaowu
# 209, Korolev
# 210, Kasli
# 211, Glendale
# 212, Ojo de Agua
# 213, Arendal
# 214, Ash Shafā
# 215, Uspenskoye
# 216, Carregado
# 217, Dacun
# 218, Clearwater
# 219, Ueda
# 220, Duyun
# 221, Kurortnyy
# 222, Obiaruku Quarters
# 223, Puerto Boyacá
# 224, Binubusan
# 225, Yun’an
# 226, Utara
# 227, Bigaa
# 228, Quitilipi
# 229, Tianyu
# 230, Baoquanshan
# 231, Novallas
# 232, Gaomiaoji
# 233, Quvasoy
# 234, Xinglong
# 235, Marteleira
# 236, Chengyue
# 237, Hostivice
# 238, Castelo
# 239, Chirkey
# 240, El Zapote
# 241, Roboré
# 242, San Mariano
# 243, Bijelo Polje
# 244, Mykonos
# 245, Mkiriwadjumoi
# 246, Jingling
# 247, Khryashchevka
# 248, Nantuo
# 249, Lotoshino
# 250, Kylmäkoski
# 251, Moxi
# 252, Ananea
# 253, Cantilan
# 254, Arroteia
# 255, Minnedosa
# 256, Brengkok
# 257, Ráquira
# 258, Guanqiao
# 259, Pasto
# 260, Naikoten Dua
# 261, Jisegumen
# 262, Pilar do Sul
# 263, Jinchang
# 264, Isla Verde
# 265, Donja Dubica
# 266, Dawung
# 267, Kapasan
# 268, Kot Sultan
# 269, Vyselki
# 270, Santo Domingo
# 271, Mutoko
# 272, Wiyayu Barat
# 273, Chantilly
# 274, Weiyuankou
# 275, Binalbagan
# 276, Bardīyah
# 277, Kahama
# 278, Xinzheng
# 279, Ipameri
# 280, Brazzaville
# 281, Boden
# 282, Yao’an
# 283, Margaharja
# 284, Laoxialu
# 285, Viana
# 286, El Calvario
# 287, Al Wardānīn
# 288, Dangmu
# 289, Fengcheng
# 290, Matou
# 291, Tinabogan
# 292, Alto de São Sebastião
# 293, Blumenau
# 294, Ko Chan
# 295, Yanglin
# 296, Pumaqangtang
# 297, Dopang
# 298, Alderetes
# 299, Jambuwerkrajan
# 300, San Jose
# 301, Fresno
# 302, Honolulu
# 303, Salerno
# 304, Sumberingin Kulon
# 305, Zhougao
# 306, Grecheskoye
# 307, Kỳ Anh
# 308, Zamboanga
# 309, Bolnisi
# 310, Borlänge
# 311, Néa Ankhíalos
# 312, Medvedovskaya
# 313, Ash Shaykh Zuwayd
# 314, Siheyuan
# 315, West Hartford
# 316, Kadugede
# 317, El Cuy
# 318, Sanshui
# 319, Bukonyo
# 320, Wolong
# 321, Kalate
# 322, Yunxi
# 323, Mbanza Congo
# 324, Nizhnyaya Omka
# 325, Mabayo
# 326, Shangani
# 327, Bakaran Kulon
# 328, Rokoy
# 329, Zhongshan
# 330, Charleston
# 331, Stockholm
# 332, Maracanaú
# 333, Nova Era
# 334, Tahara
# 335, Laocheng
# 336, Yuchi
# 337, Fortuna
# 338, Hayes
# 339, Jovellanos
# 340, Kambar
# 341, Kryevidh
# 342, Suita
# 343, Pila
# 344, Vitoria-Gasteiz
# 345, Gorobinci
# 346, Älvsjö
# 347, Scottsdale
# 348, Jinshan
# 349, Babakansari
# 350, Koktokay
# 351, Neuquén
# 352, Villa Regina
# 353, Niono
# 354, Pantijan No 2
# 355, Zaranj
# 356, Baiyanghe
# 357, Pershotravneve
# 358, Sant Cugat Del Valles
# 359, Nūbā
# 360, Az Zarbah
# 361, Veltruby
# 362, Depok
# 363, Iradan
# 364, Gaocun
# 365, Las Vegas
# 366, Smederevo
# 367, Hägersten
# 368, Klimontów
# 369, Karjalohja
# 370, Nashville
# 371, Hastings
# 372, Popielów
# 373, Jand
# 374, San Pedro
# 375, Barberena
# 376, Sargodha
# 377, Sayang Lauq
# 378, Xinli
# 379, Montepuez
# 380, Miringa
# 381, Sasovo
# 382, Subic
# 383, Põlva
# 384, Kamieniec Podolski
# 385, Shanjeev Home
# 386, Yuelai
# 387, Simabur
# 388, Thanatpin
# 389, Santa Apolonia
# 390, Chư Prông
# 391, Malamig
# 392, Lýkeio
# 393, Karlskoga
# 394, Aswan
# 395, Tembeling
# 396, Aras-asan
# 397, Drammen
# 398, Baru
# 399, Shubenka
# 400, Hwacheon
# 401, Sacramento
# 402, Cà Mau
# 403, Dateng
# 404, Andou
# 405, Salvador
# 406, Urjala
# 407, Tucano
# 408, Tabon
# 409, Santa Clara La Laguna
# 410, Zhongzhai
# 411, Caromatan
# 412, Ash Shajarah
# 413, Novonukutskiy
# 414, Subottsi
# 415, Lipce Reymontowskie
# 416, Sambogunung
# 417, La Esmeralda
# 418, Nikopol’
# 419, Giồng Riềng
# 420, Xylotymbou
# 421, Shuya
# 422, Jönköping
# 423, Jawatiwa
# 424, Ninh Hòa
# 425, Somié
# 426, Senangkhanikhom
# 427, El Hermel
# 428, Ciechanowiec
# 429, Jadho
# 430, Štitar
# 431, Almodôvar
# 432, Horní Lideč
# 433, Xixiang
# 434, El Quebrachal
# 435, Bacalan
# 436, Crateús
# 437, Baojia
# 438, Budënnovsk
# 439, Kalyny
# 440, Mekon
# 441, São Filipe
# 442, Lhuentse
# 443, L'Aigle
# 444, Sugiharjo
# 445, Buyun
# 446, Qinxi
# 447, Cola
# 448, Dolní Dvořiště
# 449, Aplahoué
# 450, Dongjin
# 451, Manorhamilton
# 452, San José
# 453, Lidoríki
# 454, Sumy
# 455, Jasienica Rosielna
# 456, Plácido de Castro
# 457, Rumelange
# 458, Sambungjaya
# 459, Datagon
# 460, Cavalões
# 461, Luleå
# 462, Szczecin
# 463, El Hajeb
# 464, Groblersdal
# 465, Tambobamba
# 466, Zürich
# 467, Isu
# 468, Senador Pompeu
# 469, Laohugang
# 470, Sugcad
# 471, Outeiro de Polima
# 472, Vurğun
# 473, Smokvica
# 474, Sinanju
# 475, Xiaoduchuan
# 476, Yunxi
# 477, Rybí
# 478, Thị Trấn Phong Thổ
# 479, Ōbu
# 480, Sé
# 481, Gvozd
# 482, San José
# 483, Saint John’s
# 484, Naji
# 485, Ban Talat Bueng
# 486, Kuching
# 487, Göteborg
# 488, Dianbu
# 489, Zhaoqing
# 490, Umpak
# 491, Ferraz de Vasconcelos
# 492, Båstad
# 493, Ostrzeszów
# 494, Il’skiy
# 495, Marseille
# 496, Baraçais
# 497, Quezon
# 498, San Juan Ermita
# 499, Manlucahoc
# 500, Créteil

# %%
counterForSortingAlgorithms = 0
listOfItems = MergeSort(listOfItems, 0, len(listOfItems)-1)
print("Time it took MergeSort to sort the list -> " + str(counterForSortingAlgorithms))
print("Now sorted: ")
printList(listOfItems)
# Out:
# Time it took MergeSort to sort the list -> 5487
# Now sorted:
# 12, Aguas del Padre
# 287, Al Wardānīn
# 120, Alchevs’k
# 298, Alderetes
# 431, Almodôvar
# 15, Alor Setar
# 292, Alto de São Sebastião
# 189, Ambilobe
# 252, Ananea
# 404, Andou
# 158, Antipolo
# 449, Aplahoué
# 396, Aras-asan
# 213, Arendal
# 3, Armenia
# 182, Armenta
# 254, Arroteia
# 214, Ash Shafā
# 412, Ash Shajarah
# 313, Ash Shaykh Zuwayd
# 394, Aswan
# 360, Az Zarbah
# 180, Babakan Baru
# 349, Babakansari
# 435, Bacalan
# 356, Baiyanghe
# 327, Bakaran Kulon
# 86, Bambous Virieux
# 485, Ban Talat Bueng
# 32, Banjar
# 437, Baojia
# 230, Baoquanshan
# 496, Baraçais
# 375, Barberena
# 276, Bardīyah
# 398, Baru
# 74, Basel
# 113, Basqal
# 73, Bern
# 16, Bhokadoke
# 227, Bigaa
# 178, Biharamulo
# 149, Bijaepasu
# 243, Bijelo Polje
# 275, Binalbagan
# 224, Binubusan
# 293, Blumenau
# 281, Boden
# 75, Bolnisi
# 309, Bolnisi
# 173, Bondoboghila
# 77, Borek
# 310, Borlänge
# 137, Boulaide
# 280, Brazzaville
# 256, Brengkok
# 105, Budapest
# 438, Budënnovsk
# 168, Buenavista
# 14, Bukonyo
# 319, Bukonyo
# 445, Buyun
# 492, Båstad
# 190, Bābolsar
# 136, Caldono
# 203, Camino Real
# 126, Campamento
# 37, Campos Gerais
# 43, Canalete
# 253, Cantilan
# 55, Caotan
# 411, Caromatan
# 216, Carregado
# 238, Castelo
# 127, Cauday
# 460, Cavalões
# 273, Chantilly
# 197, Chanuman
# 330, Charleston
# 236, Chengyue
# 162, Chilecito
# 239, Chirkey
# 390, Chư Prông
# 428, Ciechanowiec
# 102, Cincinnati
# 81, Ciroyom
# 218, Clearwater
# 447, Cola
# 436, Crateús
# 500, Créteil
# 402, Cà Mau
# 129, Cái Dầu
# 217, Dacun
# 288, Dangmu
# 459, Datagon
# 403, Dateng
# 266, Dawung
# 62, Dayuanhuizu
# 362, Depok
# 488, Dianbu
# 31, Diré
# 448, Dolní Dvořiště
# 450, Dongjin
# 265, Donja Dubica
# 297, Dopang
# 397, Drammen
# 198, Duofudu
# 220, Duyun
# 286, El Calvario
# 317, El Cuy
# 463, El Hajeb
# 427, El Hermel
# 434, El Quebrachal
# 240, El Zapote
# 27, Entre Rios
# 4, Essang
# 46, Fagatogo
# 289, Fengcheng
# 70, Fermont
# 491, Ferraz de Vasconcelos
# 123, Florencia
# 117, Fort Worth
# 337, Fortuna
# 301, Fresno
# 205, Gaocheng
# 364, Gaocun
# 232, Gaomiaoji
# 208, Gaowu
# 184, Gardanne
# 419, Giồng Riềng
# 211, Glendale
# 195, Gontar
# 201, Gonzalo Pizarro
# 345, Gorobinci
# 82, Gorodishche
# 140, Grebnevo
# 306, Grecheskoye
# 464, Groblersdal
# 258, Guanqiao
# 36, Gucheng
# 17, Gulod
# 481, Gvozd
# 29, Gândara
# 487, Göteborg
# 61, Głogówek
# 30, Hallstahammar
# 371, Hastings
# 338, Hayes
# 142, Hejiang
# 130, Hexi
# 302, Honolulu
# 145, Horad Krychaw
# 432, Horní Lideč
# 237, Hostivice
# 141, Hougang
# 110, Huancheng
# 186, Huangcun
# 25, Huapi
# 95, Huesca
# 400, Hwacheon
# 367, Hägersten
# 187, Hŭkkyo-ri
# 494, Il’skiy
# 21, Inkerman
# 279, Ipameri
# 363, Iradan
# 111, Ishimbay
# 264, Isla Verde
# 467, Isu
# 429, Jadho
# 299, Jambuwerkrajan
# 69, Jammā‘īn
# 373, Jand
# 455, Jasienica Rosielna
# 423, Jawatiwa
# 124, Jetis
# 5, Jianshan
# 263, Jinchang
# 246, Jingling
# 348, Jinshan
# 261, Jisegumen
# 169, Joaquín V. González
# 339, Jovellanos
# 49, Juegang
# 200, Junkou
# 422, Jönköping
# 132, Jāmpur
# 72, Kaca
# 316, Kadugede
# 277, Kahama
# 204, Kalapagada
# 321, Kalate
# 439, Kalyny
# 340, Kambar
# 384, Kamieniec Podolski
# 18, Kangdong-ŭp
# 267, Kapasan
# 369, Karjalohja
# 393, Karlskoga
# 210, Kasli
# 1, Kastsyukovichy
# 34, Kedian
# 191, Kelaniya
# 2, Kholmsk
# 247, Khryashchevka
# 368, Klimontów
# 52, Klinan
# 294, Ko Chan
# 350, Koktokay
# 209, Korolev
# 268, Kot Sultan
# 109, Kotlyarevskaya
# 39, Kozakai-chō
# 196, Krajan
# 174, Kribi
# 341, Kryevidh
# 486, Kuching
# 221, Kurortnyy
# 250, Kylmäkoski
# 119, Kítsi
# 307, Kỳ Anh
# 443, L'Aigle
# 417, La Esmeralda
# 91, Lae
# 144, Lamoso
# 89, Langpas
# 335, Laocheng
# 469, Laohugang
# 284, Laoxialu
# 84, Las Palmas
# 365, Las Vegas
# 63, Le Mans
# 442, Lhuentse
# 93, Liangbing
# 453, Lidoríki
# 152, Lillehammer
# 188, Limon
# 121, Lindavista
# 128, Linquan
# 50, Lin’an
# 415, Lipce Reymontowskie
# 154, Liushi
# 106, Lluka e Eperme
# 175, London
# 107, Longmiao
# 192, Longquan
# 249, Lotoshino
# 41, Luleå
# 99, Luleå
# 461, Luleå
# 94, Luna
# 392, Lýkeio
# 103, Lāliān
# 325, Mabayo
# 391, Malamig
# 7, Malayal
# 499, Manlucahoc
# 451, Manorhamilton
# 332, Maracanaú
# 115, Marechal Cândido Rondon
# 283, Margaharja
# 495, Marseille
# 235, Marteleira
# 290, Matou
# 101, Mayorga
# 79, Mbale
# 323, Mbanza Congo
# 151, Medicine Hat
# 312, Medvedovskaya
# 57, Meilisi
# 440, Mekon
# 35, Melun
# 104, Mendoza
# 68, Menggala
# 100, Mesa
# 255, Minnedosa
# 380, Miringa
# 245, Mkiriwadjumoi
# 9, Mogi Mirim
# 379, Montepuez
# 47, Morrelgonj
# 251, Moxi
# 44, Mulyadadi
# 108, Muqui
# 271, Mutoko
# 244, Mykonos
# 260, Naikoten Dua
# 484, Naji
# 161, Nanning
# 248, Nantuo
# 370, Nashville
# 351, Neuquén
# 166, New Agutaya
# 418, Nikopol’
# 424, Ninh Hòa
# 353, Niono
# 324, Nizhnyaya Omka
# 333, Nova Era
# 231, Novallas
# 413, Novonukutskiy
# 172, Novyye Kuz’minki
# 114, Nueva Ocotepeque
# 125, Nyíregyháza
# 311, Néa Ankhíalos
# 359, Nūbā
# 222, Obiaruku Quarters
# 212, Ojo de Agua
# 28, Olofström
# 66, Orodara
# 493, Ostrzeszów
# 471, Outeiro de Polima
# 98, Ozatlán
# 65, Ołpiny
# 163, Padangtikar
# 202, Palpalá
# 354, Pantijan No 2
# 56, Parista
# 26, Partille
# 259, Pasto
# 71, Pau
# 159, Peresvet
# 357, Pershotravneve
# 343, Pila
# 262, Pilar do Sul
# 54, Pinheiro
# 456, Plácido de Castro
# 372, Popielów
# 85, Preko
# 223, Puerto Boyacá
# 296, Pumaqangtang
# 171, Pushkinskiye Gory
# 383, Põlva
# 156, Qabqir
# 143, Qaffīn
# 53, Qarqīn
# 446, Qinxi
# 497, Quezon
# 228, Quitilipi
# 233, Quvasoy
# 80, Rabāţ-e Sangī-ye Pā’īn
# 19, Randuagung
# 241, Roboré
# 328, Rokoy
# 164, Ropa
# 199, Rudnya
# 457, Rumelange
# 477, Rybí
# 257, Ráquira
# 401, Sacramento
# 483, Saint John’s
# 181, Saint-Denis
# 303, Salerno
# 11, Salgar
# 405, Salvador
# 416, Sambogunung
# 458, Sambungjaya
# 22, San Diego
# 300, San Jose
# 452, San José
# 482, San José
# 498, San Juan Ermita
# 242, San Mariano
# 48, San Miguel
# 374, San Pedro
# 318, Sanshui
# 358, Sant Cugat Del Valles
# 389, Santa Apolonia
# 409, Santa Clara La Laguna
# 179, Santa Elena
# 270, Santo Domingo
# 376, Sargodha
# 381, Sasovo
# 377, Sayang Lauq
# 347, Scottsdale
# 468, Senador Pompeu
# 426, Senangkhanikhom
# 326, Shangani
# 207, Shangshuai
# 385, Shanjeev Home
# 42, Shankill
# 194, Shizukuishi
# 134, Shouchun
# 399, Shubenka
# 421, Shuya
# 83, Sidomekar
# 314, Siheyuan
# 387, Simabur
# 118, Simbal
# 153, Simuay
# 474, Sinanju
# 157, Sison
# 87, Sitajara
# 135, Skoki
# 366, Smederevo
# 473, Smokvica
# 170, Soi Dao
# 425, Somié
# 165, Stan-Bekhtemir
# 24, Stanovoye
# 331, Stockholm
# 382, Subic
# 414, Subottsi
# 470, Sugcad
# 444, Sugiharjo
# 342, Suita
# 133, Sukojember
# 304, Sumberingin Kulon
# 454, Sumy
# 76, Suren
# 462, Szczecin
# 441, São Filipe
# 146, São Torcato
# 480, Sé
# 408, Tabon
# 334, Tahara
# 51, Takamatsu-shi
# 465, Tambobamba
# 13, Tambov
# 138, Taobei
# 122, Tarragona
# 395, Tembeling
# 388, Thanatpin
# 478, Thị Trấn Phong Thổ
# 176, Thị Trấn Quảng Uyên
# 229, Tianyu
# 291, Tinabogan
# 148, Toledo
# 60, Topchikha
# 38, Torbay
# 167, Toulon
# 183, Trzebinia
# 97, Ts’khinvali
# 407, Tucano
# 185, Tuen Mun
# 177, Tulsa
# 219, Ueda
# 490, Umpak
# 20, Urechcha
# 406, Urjala
# 215, Uspenskoye
# 226, Utara
# 58, Uva
# 10, Vadstena
# 150, Velká Polom
# 361, Veltruby
# 285, Viana
# 116, Vila
# 92, Vila Nova
# 131, Viljandi
# 352, Villa Regina
# 344, Vitoria-Gasteiz
# 59, Voinjama
# 206, Voinjama
# 147, Volzhskiy
# 193, Vorob’yovo
# 45, Voronezh
# 472, Vurğun
# 269, Vyselki
# 8, Várzea Alegre
# 23, Wadeng
# 155, Wan Yai
# 274, Weiyuankou
# 139, Wenfeng Zhen
# 315, West Hartford
# 96, Wiri
# 272, Wiyayu Barat
# 320, Wolong
# 475, Xiaoduchuan
# 78, Xiluo
# 64, Xinan
# 88, Xinbu
# 234, Xinglong
# 378, Xinli
# 278, Xinzheng
# 433, Xixiang
# 420, Xylotymbou
# 6, Yangba
# 295, Yanglin
# 112, Yanglinqiao
# 160, Yanmen
# 282, Yao’an
# 67, Yasothon
# 336, Yuchi
# 386, Yuelai
# 322, Yunxi
# 476, Yunxi
# 225, Yun’an
# 308, Zamboanga
# 355, Zaranj
# 489, Zhaoqing
# 329, Zhongshan
# 410, Zhongzhai
# 305, Zhougao
# 90, Zhulin
# 466, Zürich
# 346, Älvsjö
# 40, Épinal
# 479, Ōbu
# 33, Šardice
# 430, Štitar

# %%
print("\nBinary Search with Merge Sort")
counter = 0
print("\tLooking for 'Luleå'")
print("\tFound at: " + str(binarySearchIterative(listOfItems, 'Luleå')) + " with a time of: " + str(counter))
counter = 0
print("\tLooking for 'Mexico City'") #non existent element
print("\tFound at: " + str(binarySearchIterative(listOfItems, 'Mexico City')) + " with a time of: " + str(counter))
# Out:
# Binary Search with Merge Sort
# 	Looking for 'Luleå'
# 	Found at: 249 with a time of: 1
# 	Looking for 'Mexico City'
# 	Found at: -1 with a time of: 9

# %%
# Binary Search Best Case 
print("Binary Search Best Case -> MergeSort Best Case ")
	# MergeSort Best Case 
listOfItems = readFromFile()
listOfItems = MergeSort(listOfItems, 0, len(listOfItems)-1)
counterForSortingAlgorithms = 0
listOfItems = MergeSort(listOfItems, 0, len(listOfItems)-1)
x = []
yBest = []
listToIterate = []
for i in range(len(listOfItems)):
	counter = 0
	x.append(i+1)
	listToIterate = listOfItems[:i+1]
	mid = math.floor((0 + (len(listToIterate)-1)) / 2)
	city = listToIterate[int(mid)].city
	binarySearchIterative(listToIterate, city)
	yBest.append(counterForSortingAlgorithms + counter)
print(yBest)

plt.plot( x, yBest)
plt.show()
# Out:
# Binary Search Best Case -> MergeSort Best Case
# [54, 54, 54, 54, 54, 54, 54, 54, 54, 54]

# %%
print("MergeSort Average Case")
counterForSortingAlgorithms = 0
listOfItems = readFromFile()
listOfItems = MergeSort(listOfItems, 0, len(listOfItems)-1)
yAverage = []
listToIterate = []
for i in range(len(listOfItems)):
	counter = 0
	listToIterate = listOfItems[:i+1]
	mid = math.floor((0 + (len(listToIterate)-1)) / 2)
	city = listToIterate[int(mid)].city
	binarySearchIterative(listToIterate, city)
	yAverage.append(counterForSortingAlgorithms + counter)
print(yAverage)

plt.plot( x, yBest)
plt.show()
# Out:
# MergeSort Average Case
# [54, 54, 54, 54, 54, 54, 54, 54, 54, 54]

# %%
def MergeGraf(A, p, q, r):
	global counterForSortingAlgorithms
	arrIzq = A[p:q+1]
	arrDer = A[q+1:r+1]
	izq = 0
	der = 0
	for k in xrange(p,r+1):
		if (der >= len(arrDer)) or (izq < len(arrIzq) and arrIzq[izq] < arrDer[der]):
			A[k] = arrIzq[izq]
			izq += 1
			counterForSortingAlgorithms += 1
		else:
			A[k] = arrDer[der]
			der += 1
			counterForSortingAlgorithms += 1
			

def MergeSortGraf(A, p, r):
	global counterForSortingAlgorithms
	if p >= r:
		counterForSortingAlgorithms += 1
		return
	else:
		counterForSortingAlgorithms += 1
		q = (p + r ) / 2
		MergeSortGraf(A, p, q)
		MergeSortGraf(A, q + 1, r)
		MergeGraf(A, p, q, r)
	return A

# %%
print("MergeSort Worst Case") 
randomList = []
for i in range(10):
    randomList.append(random.randint(0,400))
randomList.sort()
randomList.reverse();
counterForSortingAlgorithms = 0
listOfItems = MergeSortGraf(randomList, 0, len(randomList)-1)
yWorst = []
listToIterate = []
for i in range(len(listOfItems)):
	counter = 0
	listToIterate = randomList[:i+1]
	mid = math.floor((0 + (len(listToIterate)-1)) / 2)
	city = listToIterate[int(mid)]
	binarySearchIterativeGraf(listToIterate, city)
	yWorst.append(counterForSortingAlgorithms + counter)
print(yWorst)

plt.plot( x, yWorst)
plt.show()
# Out:
# MergeSort Worst Case
# List :  [359, 248, 236, 211, 204, 186, 170, 105, 38, 11]
# [54, 54, 54, 54, 54, 54, 54, 54, 54, 54]

# %%
# Binary Search Average Case 
print("Binary Search Average Case -> merge sort best case")

listOfItems = readFromFile()
listOfItems = MergeSort(listOfItems, 0, len(listOfItems)-1)
counterForSortingAlgorithms = 0
listOfItems = MergeSort(listOfItems, 0, len(listOfItems)-1)
x = []
yBest = []
listToIterate = []
for i in range(len(listOfItems)):
	counter = 0
	x.append(i+1)
	listToIterate = listOfItems[:i+1]
	randomElement = random.randint(0,len(listToIterate)-1)
	city = listToIterate[randomElement].city
	binarySearchIterative(listToIterate, city)
	yBest.append(counterForSortingAlgorithms + counter)
print(yBest)

plt.plot( x, yBest)
plt.show()
# Out:
# Binary Search Average Case -> merge sort best case
# Aguachica
# Chengnan
# Chengnan
# Duraznopampa
# Aguachica
# Chengnan
# Aguachica
# Fresno
# Duraznopampa
# Torre
# [54, 55, 54, 55, 55, 56, 56, 54, 56, 56]

# %%
# MergeSort Average Case 
counterForSortingAlgorithms = 0
listOfItems = readFromFile()
listOfItems = MergeSort(listOfItems, 0, len(listOfItems)-1)
yAverage = []
listToIterate = []
for i in range(len(listOfItems)):
	counter = 0
	listToIterate = listOfItems[:i+1]
	randomElement = random.randint(0,len(listToIterate)-1)
	city = listToIterate[randomElement].city
	binarySearchIterative(listToIterate, city)
	yAverage.append(counterForSortingAlgorithms + counter)
print(yAverage)

plt.plot( x, yAverage)
plt.show()
# Out:
# [54, 54, 54, 55, 55, 54, 54, 57, 55, 57]

# %%
# MergeSort Worst Case 
counterForSortingAlgorithms = 0
listOfItems = readFromFile()
listOfItems.sort()
listOfItems.reverse()
listOfItems = MergeSort(listOfItems, 0, len(listOfItems)-1)
yWorst = []
listToIterate = []
for i in range(len(listOfItems)):
	counter = 0
	listToIterate = listOfItems[:i+1]
	randomElement = random.randint(0,len(listToIterate)-1)
	city = listToIterate[randomElement].city
	binarySearchIterative(listToIterate, city)
	yWorst.append(counterForSortingAlgorithms + counter)
print(yWorst)
plt.plot( x, yWorst)
plt.show()
# Out:
# [54, 55, 55, 54, 56, 56, 56, 54, 54, 56]

# %%
# Binary Search Worst Case 
print("Binary Search Worst Case -> Merge Sort Best Case ")

listOfItems = readFromFile()
listOfItems = MergeSort(listOfItems, 0, len(listOfItems)-1)
counterForSortingAlgorithms = 0
listOfItems = MergeSort(listOfItems, 0, len(listOfItems)-1)
x = []
yBest = []
listToIterate = []
for i in range(len(listOfItems)):
	counter = 0
	x.append(i+1)
	listToIterate = listOfItems[:i+1]
	binarySearchIterative(listToIterate, "xxxxxxxx")	
	yBest.append(counterForSortingAlgorithms + counter)
print(yBest)

plt.plot( x, yBest)
plt.show()
# Out:
# Binary Search Worst Case -> Merge Sort Best Case
# [54, 55, 55, 56, 56, 56, 56, 57, 57, 57]

# %%
# MergeSort Average Case 
counterForSortingAlgorithms = 0
listOfItems = readFromFile()
listOfItems = MergeSort(listOfItems, 0, len(listOfItems)-1)
yAverage = []
listToIterate = []
for i in range(len(listOfItems)):
	counter = 0
	listToIterate = listOfItems[:i+1]
	binarySearchIterative(listToIterate, "xxxxxxxx")
	yAverage.append(counterForSortingAlgorithms + counter)
print(yAverage)
plt.plot( x, yAverage)
plt.show()
# Out:
# [54, 55, 55, 56, 56, 56, 56, 57, 57, 57]

# %%
# MergeSort Worst Case 
counterForSortingAlgorithms = 0
listOfItems = readFromFile()
listOfItems.sort()
listOfItems.reverse()
listOfItems = MergeSort(listOfItems, 0, len(listOfItems)-1)
yWorst = []
listToIterate = []
for i in range(len(listOfItems)):
	counter = 0
	listToIterate = listOfItems[:i+1]
	binarySearchIterative(listToIterate, "xxxxxxxx")
	yWorst.append(counterForSortingAlgorithms + counter)
print(yWorst)
plt.plot( x, yWorst)
plt.show()
# Out:
# [54, 55, 55, 56, 56, 56, 56, 57, 57, 57]
